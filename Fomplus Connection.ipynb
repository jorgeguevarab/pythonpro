# %%
import pyodbc
import pandas as pd

server = 'CORSA-SRV\CORSADB'
database = 'CORSA'
user = 'saint'
pwd = 'Clave.Saint'
cnnstr = 'DRIVER={ODBC Driver 17 for SQL Server};SERVER=' + server + ';DATABASE=' + database +';UID=' + user + ';PWD=' + pwd

conn = pyodbc.connect(cnnstr)
cursor = conn.cursor()
# query = 'select * from MAECXP WHERE CLI_NOMBRE like \'%MPS%\' OR CLI_NOMBRE LIKE \'IMPRESISTEM%\''
query = '''SELECT MAECXP.CLI_NOMBRE, inventariogeneral.* 
FROM inventariogeneral LEFT JOIN MAECXP ON inventariogeneral.INV_PROVEE = MAECXP.CLI_CEDULA 
ORDER BY INV_SALACT DESC, MAECXP.CLI_NOMBRE ASC'''


df = pd.read_sql(query, conn)

# %%
df.dtypes
# Out:
# CLI_NOMBRE            object
# INV_CLASE             object
# INV_GRUPO             object
# INV_LINEA             object
# INV_PROVEE            object
# INV_REFER             object
# INV_NOMBRE            object
# INV_UNDMED            object
# INV_CODIGO            object
# INV_ULTMOV    datetime64[ns]
# INV_ACTIVO              bool
# INV_PROMOC              bool
# INV_BODEGA            object
# INV_MARCA             object
# INV_MODELO            object
# INV_UBICA             object
# INV_LOTE              object
# INV_VALCOM           float64
# INV_PREVEN           float64
# INV_PORCEN           float64
# INV_CANANT           float64
# INV_VALANT           float64
# INV_CANENT           float64
# INV_VALENT           float64
# INV_CANSAL           float64
# INV_VALSAL           float64
# INV_SALACT           float64
# INV_VALACT           float64
# dtype: object

# %%
df.describe(include="all")
# Out:
# C:\Users\JORGEG~1\AppData\Local\Temp/ipykernel_15904/1985922364.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include="all")
#                 CLI_NOMBRE INV_CLASE INV_GRUPO INV_LINEA INV_PROVEE  \
# count                 7620     16706     16706     16706      16706
# unique                 263        14        52       169        265
# top     IMPRESISTEM S.A.S.        10      2300       232
# freq                   629      4807      1738      1159       9086
# first                  NaN       NaN       NaN       NaN        NaN
# last                   NaN       NaN       NaN       NaN        NaN
# mean                   NaN       NaN       NaN       NaN        NaN
# std                    NaN       NaN       NaN       NaN        NaN
# ...

# %%
df.head(10)
# Out:
#                                  CLI_NOMBRE INV_CLASE INV_GRUPO INV_LINEA  \
# 0                                      None        90      9900       999
# 1                                      None        90      9900       999
# 2                                      None        90      9900       999
# 3  NAL. DE TORNILLOS Y R. /ELDA HERNANDEZ J        60      6900       691
# 4                        LAMINAS & DOBLECES        60      6500       657
# 5                        FABRIFOLDER S.A.S.        10      1300       131
# 6  NAL. DE TORNILLOS Y R. /ELDA HERNANDEZ J        60      6500       657
# 7                           DISPAPELES S.A.        10      1100       115
# 8                            MEGASEO S.A.S.        30      3300       331
# 9                   SERVIMAT COLOMBIA S.A.S        90      9900       999
#
#   INV_PROVEE   INV_REFER                                         INV_NOMBRE  \
# 0             999ETP0001                 BOLSA "CORSA" #3  20*30*0.5 CMS
# ...

# %%
# df.index
# df.columns
rows = df.to_numpy()
df.T
df.sort_values(by='INV_REFER')
skus = df.loc[:, ['CLI_NOMBRE','INV_NOMBRE', 'INV_SALACT']]
skus.describe(include="all")
# Out:
#                 CLI_NOMBRE                                      INV_NOMBRE  \
# count                  115                                             186
# unique                  14                                             164
# top     IMPRESISTEM S.A.S.  MONITOR HP 19.5" LED HP V201 E6W38AA   E6W38AA
# freq                    49                                               8
# mean                   NaN                                             NaN
# std                    NaN                                             NaN
# min                    NaN                                             NaN
# 25%                    NaN                                             NaN
# 50%                    NaN                                             NaN
# 75%                    NaN                                             NaN
# max                    NaN                                             NaN
#
#         INV_SALACT
# count   186.000000
# unique         NaN
# ...
